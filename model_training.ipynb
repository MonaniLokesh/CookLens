# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.8/883.8 kB 20.5 MB/s eta 0:00:0000:01
# ...

# %%
# !yolo task=detect mode=train model='/kaggle/input/recipe_detection_12_ingredient/pytorch/default/1/best 889.pt' data='/kaggle/input/recipe/datasets/data.yaml' epochs=100 imgsz=640 plots=True freeze=0
# Out:
# Ultralytics 8.3.29 🚀 Python-3.10.14 torch-2.4.0 CUDA:0 (Tesla P100-PCIE-16GB, 16269MiB)
# ...

# %%
# ginger has lower metrics it may need more training data or further optimization for improved accuracy.
